# %% [markdown]
# # ResNet with 2 residual layers
#
# Upload [resnet2l.py](https://github.com/JinchengLiang/DLminiproject/blob/main/resnet2l.py) frist.

# %%
from resnet2l import *
from torchsummary import summary
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## ResNet Parameters

# %% [markdown]
# ### ResNet26

# %% [markdown]
# #### Let's try $B = [6, 6]$

# %%
net = ResNet(BasicBlock, [6, 6])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#         BasicBlock-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %% [markdown]
# Successful!

# %% [markdown]
# ### ResNet50

# %% [markdown]
# #### Let's try $B = [12, 12]$

# %%
net = ResNet(BasicBlock, [12, 12])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#         BasicBlock-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %% [markdown]
# Successful!

# %% [markdown]
# ### ResNet52

# %% [markdown]
# #### Let's try $B =[13, 12]$

# %%
net = ResNet(BasicBlock, [13, 12])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#         BasicBlock-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %% [markdown]
# Successful!

# %% [markdown]
# #### Let's try $B = [12, 13]$

# %%
net = ResNet(BasicBlock, [12, 13])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#         BasicBlock-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %% [markdown]
# Successful!

# %% [markdown]
# ### ResNet54

# %% [markdown]
# #### Let's try $B = [13, 13]$

# %%
net = ResNet(BasicBlock, [13, 13])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#         BasicBlock-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %% [markdown]
# Successful!

# %% [markdown]
# ### ResNet56

# %% [markdown]
# #### Let's try $B = [14, 13]$

# %%
net = ResNet(BasicBlock, [14, 13])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#         BasicBlock-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %% [markdown]
# Successful!

# %% [markdown]
# #### Let's try $B = [13, 14]$

# %%
net = ResNet(BasicBlock, [13, 14])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#         BasicBlock-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %% [markdown]
# Failed!
